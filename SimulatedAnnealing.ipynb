# %% [markdown]
# # Import e costanti

# %%
import random
import numpy
import math

TEMPERATURA_INIZIALE = 30
TEMPERATURA_FINALE = 0.2
ALFA = 0.99
STEPS_PER_CHANGE = 100

DIMENSIONE = 32

# %% [markdown]
# # Tweak e inizializzazione

# %%
def tweak(sol):
    sol_copy = numpy.copy(sol)
    x = random.randint(0,DIMENSIONE-1)
    y = random.randint(0,DIMENSIONE-1)
    while x==y:
        y = random.randint(0,DIMENSIONE-1)
    temp = sol_copy[y]
    sol_copy[y] = sol_copy[x] 
    sol_copy[x] = temp
    return sol_copy

def inizializza(sol):
    for c in range(0,DIMENSIONE-1):
        tweak(sol)
    return tweak(sol)

# %% [markdown]
# # Calcolo dell'energia (minacce)

# %%
def energia(matrix):
    board  = [[0] * DIMENSIONE for i in range(DIMENSIONE)] 
    for i in range(0,DIMENSIONE):
        board[i][matrix[i]]='Q'
        
    dx = [-1,1,-1,1]
    dy = [-1,1,1,-1]
    
    conflitti = 0

    for i in range(0,DIMENSIONE):
        x=i
        y=matrix[i]
        for j in range(0,4):
            tempx = x
            tempy = y
            while (True):
                tempx = tempx + dx[j]
                tempy = tempy + dy[j]
                if ((tempx < 0) or 
                    (tempx >= DIMENSIONE) or
                    (tempy < 0) or 
                    (tempy >= DIMENSIONE)):
                    break
                if (board[tempx][tempy]=='Q'):
                    conflitti = conflitti+1
    return conflitti

# %% [markdown]
# # Stampa

# %%
def stampa(sol):
    board = [[0] * DIMENSIONE for i in range(DIMENSIONE)] 

    for x in range(0,DIMENSIONE):
        board[x][sol[x]]='Q'
    print("SCHACCHIERA")
    for y in range(0,DIMENSIONE):
        for x in range(0,DIMENSIONE):
            if(board[x][y]=='Q'):
                print("Q"),
            else:
                print("."),
        print("\n")
    print("\n\n")

# %% [markdown]
# # Simulated Annealing

# %%
current = range(0,DIMENSIONE)
working = range(0,DIMENSIONE)
best = range (0,DIMENSIONE)

current = inizializza(current)
current_energy = energia(current)

best_energy = DIMENSIONE*(DIMENSIONE-1)

working = numpy.copy(current)
working_energy = current_energy

temperature = TEMPERATURA_INIZIALE

while (temperature > TEMPERATURA_FINALE and best_energy!=0):
    print("TEMPERATURA: "),    
    print(temperature)
    for step in range(0,STEPS_PER_CHANGE):
        useNew = False
        working = tweak(working)
        working_energy = energia(working)
    
        if (working_energy < current_energy):
            useNew = True
        else:
            test = random.random()
            delta = working_energy - current_energy
            calc = math.exp(-delta/temperature)
            if (calc > test):
                useNew = True
                
        if (useNew):
            current = numpy.copy(working)
            current_energy = working_energy
            
            if (current_energy < best_energy):
                best = numpy.copy(working)
                best_energy = energia(best)
            useNew = False
        else:
            working = numpy.copy(current)
            working_energy = energia(working)
            
    print("best_energy="),
    print(best_energy)            
    temperature = temperature * ALFA

stampa(best)
# Out:
# TEMPERATURA:  30
# best_energy= 22
# TEMPERATURA:  29.7
# best_energy= 22
# TEMPERATURA:  29.403
# best_energy= 22
# TEMPERATURA:  29.10897
# best_energy= 22
# TEMPERATURA:  28.8178803
# best_energy= 22
# TEMPERATURA:  28.529701497
# best_energy= 22
# TEMPERATURA:  28.244404482
# TEMPERATURA:  4.86509670033
# best_energy= 14
# TEMPERATURA:  4.81644573333
# best_energy= 14
# TEMPERATURA:  4.76828127599
# best_energy= 14
# TEMPERATURA:  4.72059846323
# best_energy= 14
# TEMPERATURA:  4.6733924786
# best_energy= 14
# TEMPERATURA:  4.62665855382
# best_energy= 14
# TEMPERATURA:  4.58039196828
# best_energy= 14
# TEMPERATURA:  4.53458804859
# best_energy= 14
# TEMPERATURA:  4.48924216811
# best_energy= 14
# TEMPERATURA:  4.44434974643
# best_energy= 12
# TEMPERATURA:  4.39990624896
# best_energy= 12
# TEMPERATURA:  4.35590718647
# best_energy= 12
# TEMPERATURA:  4.31234811461
# best_energy= 12
# TEMPERATURA:  4.26922463346
# best_energy= 12
# TEMPERATURA:  4.22653238713
# best_energy= 12
# TEMPERATURA:  4.18426706326
# best_energy= 12
# TEMPERATURA:  4.14242439262
# best_energy= 12
# TEMPERATURA:  4.1010001487
# best_energy= 12
# TEMPERATURA:  4.05999014721
# best_energy= 12
# TEMPERATURA:  4.01939024574
# best_energy= 12
# TEMPERATURA:  3.97919634328
# best_energy= 12
# TEMPERATURA:  3.93940437985
# best_energy= 12
# TEMPERATURA:  3.90001033605
# best_energy= 12
# TEMPERATURA:  3.86101023269
# best_energy= 12
# TEMPERATURA:  3.82240013036
# best_energy= 12
# TEMPERATURA:  3.78417612906
# best_energy= 12
# TEMPERATURA:  3.74633436777
# best_energy= 12
# TEMPERATURA:  3.70887102409
# best_energy= 12
# TEMPERATURA:  3.67178231385
# best_energy= 12
# TEMPERATURA:  3.63506449071
# best_energy= 12
# TEMPERATURA:  3.5987138458
# best_energy= 12
# TEMPERATURA:  3.56272670735
# best_energy= 12
# TEMPERATURA:  3.52709944027
# best_energy= 12
# TEMPERATURA:  3.49182844587
# best_energy= 12
# TEMPERATURA:  3.45691016141
# best_energy= 12
# TEMPERATURA:  3.4223410598
# best_energy= 12
# TEMPERATURA:  3.3881176492
# best_energy= 12
# TEMPERATURA:  3.35423647271
# best_energy= 12
# TEMPERATURA:  3.32069410798
# best_energy= 12
# TEMPERATURA:  3.2874871669
# best_energy= 12
# TEMPERATURA:  3.25461229523
# best_energy= 12
# TEMPERATURA:  3.22206617228
# best_energy= 12
# TEMPERATURA:  3.18984551056
# best_energy= 12
# TEMPERATURA:  3.15794705545
# best_energy= 12
# TEMPERATURA:  3.1263675849
# best_energy= 12
# TEMPERATURA:  3.09510390905
# best_energy= 12
# TEMPERATURA:  3.06415286996
# best_energy= 12
# TEMPERATURA:  3.03351134126
# best_energy= 12
# TEMPERATURA:  3.00317622784
# best_energy= 12
# TEMPERATURA:  2.97314446557
# best_energy= 12
# TEMPERATURA:  2.94341302091
# best_energy= 12
# TEMPERATURA:  2.9139788907
# best_energy= 12
# TEMPERATURA:  2.88483910179
# best_energy= 12
# TEMPERATURA:  2.85599071078
# best_energy= 12
# TEMPERATURA:  2.82743080367
# best_energy= 12
# TEMPERATURA:  2.79915649563
# best_energy= 12
# TEMPERATURA:  2.77116493068
# best_energy= 12
# TEMPERATURA:  2.74345328137
# best_energy= 12
# TEMPERATURA:  2.71601874856
# best_energy= 12
# TEMPERATURA:  2.68885856107
# best_energy= 12
# TEMPERATURA:  2.66196997546
# best_energy= 10
# TEMPERATURA:  2.6353502757
# best_energy= 10
# TEMPERATURA:  2.60899677295
# best_energy= 10
# TEMPERATURA:  2.58290680522
# best_energy= 10
# TEMPERATURA:  2.55707773717
# best_energy= 10
# TEMPERATURA:  2.53150695979
# best_energy= 10
# TEMPERATURA:  2.5061918902
# best_energy= 10
# TEMPERATURA:  2.48112997129
# best_energy= 10
# TEMPERATURA:  2.45631867158
# best_energy= 10
# TEMPERATURA:  2.43175548487
# best_energy= 10
# TEMPERATURA:  2.40743793002
# best_energy= 10
# TEMPERATURA:  2.38336355072
# best_energy= 10
# TEMPERATURA:  2.35952991521
# best_energy= 10
# TEMPERATURA:  2.33593461606
# best_energy= 10
# TEMPERATURA:  2.3125752699
# best_energy= 10
# TEMPERATURA:  2.2894495172
# best_energy= 10
# TEMPERATURA:  2.26655502203
# best_energy= 10
# TEMPERATURA:  2.24388947181
# best_energy= 10
# TEMPERATURA:  2.22145057709
# best_energy= 10
# TEMPERATURA:  2.19923607132
# best_energy= 10
# TEMPERATURA:  2.1772437106
# best_energy= 10
# TEMPERATURA:  2.1554712735
# best_energy= 10
# TEMPERATURA:  2.13391656076
# best_energy= 10
# TEMPERATURA:  2.11257739515
# best_energy= 10
# TEMPERATURA:  2.0914516212
# best_energy= 10
# TEMPERATURA:  2.07053710499
# best_energy= 10
# TEMPERATURA:  2.04983173394
# best_energy= 10
# TEMPERATURA:  2.0293334166
# best_energy= 10
# TEMPERATURA:  2.00904008244
# best_energy= 10
# TEMPERATURA:  1.98894968161
# best_energy= 10
# TEMPERATURA:  1.9690601848
# best_energy= 10
# TEMPERATURA:  1.94936958295
# best_energy= 10
# TEMPERATURA:  1.92987588712
# best_energy= 10
# TEMPERATURA:  1.91057712825
# best_energy= 10
# TEMPERATURA:  1.89147135696
# best_energy= 6
# TEMPERATURA:  1.87255664339
# best_energy= 6
# TEMPERATURA:  1.85383107696
# best_energy= 6
# TEMPERATURA:  1.83529276619
# best_energy= 6
# TEMPERATURA:  1.81693983853
# best_energy= 6
# TEMPERATURA:  1.79877044014
# best_energy= 6
# TEMPERATURA:  1.78078273574
# best_energy= 6
# TEMPERATURA:  1.76297490839
# best_energy= 6
# TEMPERATURA:  1.7453451593
# best_energy= 6
# TEMPERATURA:  1.72789170771
# best_energy= 6
# TEMPERATURA:  1.71061279063
# best_energy= 6
# TEMPERATURA:  1.69350666272
# best_energy= 6
# TEMPERATURA:  1.6765715961
# best_energy= 6
# TEMPERATURA:  1.65980588014
# best_energy= 6
# TEMPERATURA:  1.64320782134
# best_energy= 6
# TEMPERATURA:  1.62677574312
# best_energy= 6
# TEMPERATURA:  1.61050798569
# best_energy= 6
# TEMPERATURA:  1.59440290583
# best_energy= 6
# TEMPERATURA:  1.57845887678
# best_energy= 6
# TEMPERATURA:  1.56267428801
# best_energy= 6
# TEMPERATURA:  1.54704754513
# best_energy= 6
# TEMPERATURA:  1.53157706968
# best_energy= 6
# TEMPERATURA:  1.51626129898
# best_energy= 6
# TEMPERATURA:  1.50109868599
# best_energy= 6
# TEMPERATURA:  1.48608769913
# best_energy= 6
# TEMPERATURA:  1.47122682214
# best_energy= 6
# TEMPERATURA:  1.45651455392
# best_energy= 6
# TEMPERATURA:  1.44194940838
# best_energy= 6
# TEMPERATURA:  1.42752991429
# best_energy= 6
# TEMPERATURA:  1.41325461515
# best_energy= 6
# TEMPERATURA:  1.399122069
# best_energy= 6
# TEMPERATURA:  1.38513084831
# best_energy= 6
# TEMPERATURA:  1.37127953983
# best_energy= 6
# TEMPERATURA:  1.35756674443
# best_energy= 6
# TEMPERATURA:  1.34399107698
# best_energy= 6
# TEMPERATURA:  1.33055116621
# best_energy= 6
# TEMPERATURA:  1.31724565455
# best_energy= 6
# TEMPERATURA:  1.30407319801
# best_energy= 6
# TEMPERATURA:  1.29103246603
# best_energy= 6
# TEMPERATURA:  1.27812214137
# best_energy= 6
# TEMPERATURA:  1.26534091995
# best_energy= 6
# TEMPERATURA:  1.25268751075
# best_energy= 6
# TEMPERATURA:  1.24016063565
# best_energy= 6
# TEMPERATURA:  1.22775902929
# best_energy= 6
# TEMPERATURA:  1.215481439
# best_energy= 6
# TEMPERATURA:  1.20332662461
# best_energy= 6
# TEMPERATURA:  1.19129335836
# best_energy= 6
# TEMPERATURA:  1.17938042478
# best_energy= 6
# TEMPERATURA:  1.16758662053
# best_energy= 6
# TEMPERATURA:  1.15591075432
# best_energy= 6
# TEMPERATURA:  1.14435164678
# best_energy= 6
# TEMPERATURA:  1.13290813031
# best_energy= 6
# TEMPERATURA:  1.12157904901
# best_energy= 6
# TEMPERATURA:  1.11036325852
# best_energy= 6
# TEMPERATURA:  1.09925962593
# best_energy= 6
# TEMPERATURA:  1.08826702967
# best_energy= 6
# TEMPERATURA:  1.07738435938
# best_energy= 6
# TEMPERATURA:  1.06661051578
# best_energy= 6
# TEMPERATURA:  1.05594441063
# best_energy= 6
# TEMPERATURA:  1.04538496652
# best_energy= 6
# TEMPERATURA:  1.03493111685
# best_energy= 6
# TEMPERATURA:  1.02458180569
# best_energy= 6
# TEMPERATURA:  1.01433598763
# best_energy= 6
# TEMPERATURA:  1.00419262775
# best_energy= 4
# TEMPERATURA:  0.994150701476
# best_energy= 4
# TEMPERATURA:  0.984209194461
# best_energy= 4
# TEMPERATURA:  0.974367102516
# best_energy= 4
# TEMPERATURA:  0.964623431491
# best_energy= 4
# TEMPERATURA:  0.954977197176
# best_energy= 4
# TEMPERATURA:  0.945427425204
# best_energy= 4
# TEMPERATURA:  0.935973150952
# best_energy= 4
# TEMPERATURA:  0.926613419443
# best_energy= 4
# TEMPERATURA:  0.917347285248
# best_energy= 4
# TEMPERATURA:  0.908173812396
# best_energy= 4
# TEMPERATURA:  0.899092074272
# best_energy= 4
# TEMPERATURA:  0.890101153529
# best_energy= 4
# TEMPERATURA:  0.881200141994
# best_energy= 4
# TEMPERATURA:  0.872388140574
# best_energy= 4
# TEMPERATURA:  0.863664259168
# best_energy= 4
# TEMPERATURA:  0.855027616577
# best_energy= 4
# TEMPERATURA:  0.846477340411
# best_energy= 4
# TEMPERATURA:  0.838012567007
# best_energy= 4
# TEMPERATURA:  0.829632441337
# best_energy= 4
# TEMPERATURA:  0.821336116923
# best_energy= 4
# TEMPERATURA:  0.813122755754
# best_energy= 4
# TEMPERATURA:  0.804991528197
# best_energy= 4
# TEMPERATURA:  0.796941612915
# best_energy= 4
# TEMPERATURA:  0.788972196785
# best_energy= 4
# TEMPERATURA:  0.781082474818
# best_energy= 4
# TEMPERATURA:  0.773271650069
# best_energy= 4
# TEMPERATURA:  0.765538933569
# best_energy= 4
# TEMPERATURA:  0.757883544233
# best_energy= 4
# TEMPERATURA:  0.750304708791
# best_energy= 4
# TEMPERATURA:  0.742801661703
# best_energy= 4
# TEMPERATURA:  0.735373645086
# best_energy= 4
# TEMPERATURA:  0.728019908635
# best_energy= 4
# TEMPERATURA:  0.720739709549
# best_energy= 4
# TEMPERATURA:  0.713532312453
# best_energy= 4
# TEMPERATURA:  0.706396989329
# best_energy= 4
# TEMPERATURA:  0.699333019435
# best_energy= 4
# TEMPERATURA:  0.692339689241
# best_energy= 2
# TEMPERATURA:  0.685416292349
# best_energy= 2
# TEMPERATURA:  0.678562129425
# best_energy= 2
# TEMPERATURA:  0.671776508131
# best_energy= 2
# TEMPERATURA:  0.665058743049
# best_energy= 2
# TEMPERATURA:  0.658408155619
# best_energy= 2
# TEMPERATURA:  0.651824074063
# best_energy= 2
# TEMPERATURA:  0.645305833322
# best_energy= 2
# TEMPERATURA:  0.638852774989
# best_energy= 2
# TEMPERATURA:  0.632464247239
# best_energy= 2
# TEMPERATURA:  0.626139604767
# best_energy= 2
# TEMPERATURA:  0.619878208719
# best_energy= 2
# TEMPERATURA:  0.613679426632
# best_energy= 2
# TEMPERATURA:  0.607542632365
# best_energy= 2
# TEMPERATURA:  0.601467206042
# best_energy= 2
# TEMPERATURA:  0.595452533981
# best_energy= 2
# TEMPERATURA:  0.589498008642
# best_energy= 2
# TEMPERATURA:  0.583603028555
# best_energy= 2
# TEMPERATURA:  0.57776699827
# best_energy= 2
# TEMPERATURA:  0.571989328287
# best_energy= 2
# TEMPERATURA:  0.566269435004
# best_energy= 2
# TEMPERATURA:  0.560606740654
# best_energy= 0
# SCHACCHIERA
# . . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . .
#
# . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . .
#
# . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q .
#
# . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . .
#
# . . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . . .
#
# . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . .
#
# . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . .
#
# Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q
#
# . . . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . .
#
# . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . .
#
# . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . .
#
# . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . . . . . . Q . . . . . . . . . . . . . .
#
# . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . .
